# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from glob import glob
import os

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 自相关性函数
def autocorrelation(data, lag=1):
    return np.corrcoef(data[:-lag], data[lag:])[0, 1]

# 定义分析函数
def analyze_file(file_path):
    # 读取CSV文件
    data = pd.read_csv(file_path, skiprows=1)
    
    # 将 X 和 Y 转换为数值类型，忽略非数值内容并用 NaN 替代
    X = pd.to_numeric(data.iloc[:, 0], errors='coerce')
    Y = pd.to_numeric(data.iloc[:, 1], errors='coerce')
    
    # 删除包含 NaN 的行
    X = X.dropna().reset_index(drop=True)
    Y = Y.dropna().reset_index(drop=True)
    
    # 确保 X 和 Y 的长度一致
    min_length = min(len(X), len(Y))
    X = X[:min_length]
    Y = Y[:min_length]

    # 计算相关性
    correlation = np.corrcoef(X, Y)[0, 1]
    print(f"{file_path} - X-Y 相关性: {correlation}")

    # 计算 X 和 Y 的自相关性
    autocorr_X = autocorrelation(X)
    autocorr_Y = autocorrelation(Y)
    print(f"{file_path} - X 数据自相关性: {autocorr_X}")
    print(f"{file_path} - Y 数据自相关性: {autocorr_Y}")

    # 正态分布拟合
    mu_X, std_X = stats.norm.fit(X)
    mu_Y, std_Y = stats.norm.fit(Y)

    # 绘制图形
    plt.figure(figsize=(14, 10))

    # X 的正态分布拟合
    plt.subplot(2, 2, 1)
    plt.hist(X, bins=30, density=True, alpha=0.6, color='blue')
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = stats.norm.pdf(x, mu_X, std_X)
    plt.plot(x, p, 'k', linewidth=2)
    plt.title(f'X 的正态分布拟合 \n 均值 = {mu_X:.4e}, 标准差 = {std_X:.4e}')

    # Y 的正态分布拟合
    plt.subplot(2, 2, 2)
    plt.hist(Y, bins=30, density=True, alpha=0.6, color='red')
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = stats.norm.pdf(x, mu_Y, std_Y)
    plt.plot(x, p, 'k', linewidth=2)
    plt.title(f'Y 的正态分布拟合 \n 均值 = {mu_Y:.4e}, 标准差 = {std_Y:.4e}')

    # 卡方检验
    bins = 10
    X_binned, _ = np.histogram(X, bins=bins)
    Y_binned, _ = np.histogram(Y, bins=bins)
    chi2_val, p_val = stats.chisquare(Y_binned, f_exp=X_binned)
    print(f"{file_path} - 简化卡方值: {chi2_val}, p 值: {p_val}")

    # X-Y 散点图
    plt.subplot(2, 2, 3)
    plt.scatter(X, Y, alpha=0.5)
    plt.title(f"X-Y 相关性: {correlation:.4e}")
    plt.xlabel("X")
    plt.ylabel("Y")

    # 自相关性图
    lags = range(1, 11)
    autocorr_X_vals = [autocorrelation(X, lag) for lag in lags]
    autocorr_Y_vals = [autocorrelation(Y, lag) for lag in lags]
    plt.subplot(2, 2, 4)
    plt.plot(lags, autocorr_X_vals, marker='o', label="X 自相关")
    plt.plot(lags, autocorr_Y_vals, marker='o', label="Y 自相关")
    plt.xlabel("滞后")
    plt.ylabel("自相关性")
    plt.title("X 和 Y 的自相关性")
    plt.legend()

    plt.tight_layout()
    plt.suptitle(f"{os.path.basename(file_path)} 分析结果", y=1.02)
    plt.show()

# 批量读取 CSV 文件路径
csv_files = glob('D1-TaLEs-Second-locally/*.csv')  # 替换为文件所在目录

# 对每个 CSV 文件执行分析
for file_path in csv_files:
    analyze_file(file_path)
# Out:
# D1-TaLEs-Second-locally\Data1.csv - X-Y 相关性: 0.011880723882479752
# D1-TaLEs-Second-locally\Data1.csv - X 数据自相关性: 0.018798390984191494
# D1-TaLEs-Second-locally\Data1.csv - Y 数据自相关性: -0.001794624607396517
# D1-TaLEs-Second-locally\Data1.csv - 简化卡方值: 432.4748276188458, p 值: 1.595701958997669e-87
# D1-TaLEs-Second-locally\Data2.csv - X-Y 相关性: 0.03442999104323005
# D1-TaLEs-Second-locally\Data2.csv - X 数据自相关性: 0.0011527574205311877
# D1-TaLEs-Second-locally\Data2.csv - Y 数据自相关性: 0.006407588426252173
# D1-TaLEs-Second-locally\Data2.csv - 简化卡方值: 185.51828137717766, p 值: 3.563189077262581e-35
# D1-TaLEs-Second-locally\Data3.csv - X-Y 相关性: 0.02650674963908547
# D1-TaLEs-Second-locally\Data3.csv - X 数据自相关性: 0.04341096432928284
# D1-TaLEs-Second-locally\Data3.csv - Y 数据自相关性: -0.005491556209960784
# D1-TaLEs-Second-locally\Data3.csv - 简化卡方值: inf, p 值: 0.0
# c:\Users\TaLEsCuber\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:7985: RuntimeWarning: divide by zero encountered in divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# D1-TaLEs-Second-locally\Data4.csv - X-Y 相关性: -0.01784647768918537
# D1-TaLEs-Second-locally\Data4.csv - X 数据自相关性: -0.006325737788013399
# D1-TaLEs-Second-locally\Data4.csv - Y 数据自相关性: -0.0028238265098653728
# D1-TaLEs-Second-locally\Data4.csv - 简化卡方值: 335.9323030060088, p 值: 6.094652362247414e-67
# D1-TaLEs-Second-locally\Data5.csv - X-Y 相关性: 0.029481124395081555
# D1-TaLEs-Second-locally\Data5.csv - X 数据自相关性: -0.08338675536652211
# D1-TaLEs-Second-locally\Data5.csv - Y 数据自相关性: -0.08346377877650071
# D1-TaLEs-Second-locally\Data5.csv - 简化卡方值: 27.181454806428427, p 值: 0.0013052779421711485
# D1-TaLEs-Second-locally\Data6.csv - X-Y 相关性: 0.023440308964888287
# D1-TaLEs-Second-locally\Data6.csv - X 数据自相关性: 0.010092767426939408
# D1-TaLEs-Second-locally\Data6.csv - Y 数据自相关性: -0.01844675371376273
# D1-TaLEs-Second-locally\Data6.csv - 简化卡方值: 298.93969929485314, p 值: 4.3810933822293695e-59
# D1-TaLEs-Second-locally\Data7.csv - X-Y 相关性: -4.9879029455276944e-05
# D1-TaLEs-Second-locally\Data7.csv - X 数据自相关性: -0.03641218706918292
# D1-TaLEs-Second-locally\Data7.csv - Y 数据自相关性: 0.015090238895838501
# D1-TaLEs-Second-locally\Data7.csv - 简化卡方值: 212.41058638059687, p 值: 8.239609064666644e-41
# D1-TaLEs-Second-locally\Data8.csv - X-Y 相关性: -0.012854792564361379
# D1-TaLEs-Second-locally\Data8.csv - X 数据自相关性: 0.010835126865406263
# D1-TaLEs-Second-locally\Data8.csv - Y 数据自相关性: -0.028092062459407395
# D1-TaLEs-Second-locally\Data8.csv - 简化卡方值: 265.30594891373767, p 值: 5.820138032835476e-52
# D1-TaLEs-Second-locally\DataB1.csv - X-Y 相关性: -0.04704597353555213
# D1-TaLEs-Second-locally\DataB1.csv - X 数据自相关性: 0.2275464611321707
# D1-TaLEs-Second-locally\DataB1.csv - Y 数据自相关性: 0.2144262997519772
# D1-TaLEs-Second-locally\DataB1.csv - 简化卡方值: 598.2944391622026, p 值: 4.864747497578803e-123
# D1-TaLEs-Second-locally\DataB2.csv - X-Y 相关性: -0.006274727356902973
# D1-TaLEs-Second-locally\DataB2.csv - X 数据自相关性: -0.3670435493193704
# D1-TaLEs-Second-locally\DataB2.csv - Y 数据自相关性: -0.34479030900986823
# D1-TaLEs-Second-locally\DataB2.csv - 简化卡方值: 9.718323302522519, p 值: 0.3737661448336904
# D1-TaLEs-Second-locally\DataB3.csv - X-Y 相关性: -0.010147375443442325
# D1-TaLEs-Second-locally\DataB3.csv - X 数据自相关性: 0.027214478917164803
# D1-TaLEs-Second-locally\DataB3.csv - Y 数据自相关性: 0.00020770293304617953
# D1-TaLEs-Second-locally\DataB3.csv - 简化卡方值: 232.17790306718132, p 值: 5.721503298718071e-45
# D1-TaLEs-Second-locally\DataB4.csv - X-Y 相关性: -0.051583639364155956
# D1-TaLEs-Second-locally\DataB4.csv - X 数据自相关性: -0.003505162550115302
# D1-TaLEs-Second-locally\DataB4.csv - Y 数据自相关性: -0.001412900831544276
# D1-TaLEs-Second-locally\DataB4.csv - 简化卡方值: 61.451436227041675, p 值: 7.034446713120897e-10
# D1-TaLEs-Second-locally\DataB5.csv - X-Y 相关性: 0.02111516538287791
# D1-TaLEs-Second-locally\DataB5.csv - X 数据自相关性: -0.838607511818545
# D1-TaLEs-Second-locally\DataB5.csv - Y 数据自相关性: -0.8490155719730712
# D1-TaLEs-Second-locally\DataB5.csv - 简化卡方值: 153.2540611525064, p 值: 1.8664823775479555e-28
# D1-TaLEs-Second-locally\DataB6.csv - X-Y 相关性: 0.019640585713567308
# D1-TaLEs-Second-locally\DataB6.csv - X 数据自相关性: -0.006007884396531518
# D1-TaLEs-Second-locally\DataB6.csv - Y 数据自相关性: 0.029553516186064156
# D1-TaLEs-Second-locally\DataB6.csv - 简化卡方值: 44.450631029698506, p 值: 1.1656058588869648e-06
# D1-TaLEs-Second-locally\DataB7.csv - X-Y 相关性: -0.010427502664259987
# D1-TaLEs-Second-locally\DataB7.csv - X 数据自相关性: -0.05161071701349975
# D1-TaLEs-Second-locally\DataB7.csv - Y 数据自相关性: -0.02328860810172036
# D1-TaLEs-Second-locally\DataB7.csv - 简化卡方值: 50.871561243707355, p 值: 7.382844609331498e-08
# D1-TaLEs-Second-locally\DataB8.csv - X-Y 相关性: 0.0032934233292518586
# D1-TaLEs-Second-locally\DataB8.csv - X 数据自相关性: 0.022435041954673645
# D1-TaLEs-Second-locally\DataB8.csv - Y 数据自相关性: 0.030194360888000142
# D1-TaLEs-Second-locally\DataB8.csv - 简化卡方值: 86.02753291506038, p 值: 1.0168957209950557e-14
